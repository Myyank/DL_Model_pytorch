# %%
#@title Mount your Google Drive
# If you run this notebook locally or on a cluster (i.e. not on Google Colab)
# you can delete this cell which is specific to Google Colab. You may also
# change the paths for data/logs in Arguments below.
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from google.colab import drive
drive.mount('/content/gdrive')

# %%
import sys
import os
import shutil
import warnings

folder = "Your path to assignment folder" #@param {type:"string"}
# !ln -Ts "$folder" /content/assignment 2> /dev/null

# Add the assignment folder to Python path
if '/content/assignment' not in sys.path:
  sys.path.insert(0, '/content/assignment')

# Check if CUDA is available
import torch
if not torch.cuda.is_available():
  warnings.warn('CUDA is not available.')
# Out:
# <ipython-input-2-3cf26c08f17e>:21: UserWarning: CUDA is not available.
#   warnings.warn('CUDA is not available.')

# %% [markdown]
# ### Running on GPU
# For this assignment, it will be necessary to run your experiments on GPU. To make sure the notebook is running on GPU, you can change the notebook settings with
# * (EN) `Edit > Notebook Settings`
# * (FR) `Modifier > Paramètres du notebook`

# %%
# %matplotlib inline
import warnings
from dataclasses import dataclass
import torch
from torch import optim
from torchvision.datasets import CIFAR10
from torchvision import transforms
from utils import seed_experiment, to_device, cross_entropy_loss, compute_accuracy,generate_plots
from config import get_config_parser
import json
from mlp import MLP
from resnet18 import ResNet18
from mlpmixer import MLPMixer
from tqdm import tqdm
from torch.utils.data import DataLoader
import time
import os

# %% [markdown]
# # Local Test
# Before run the experiment, here are some local test cases you can run for sanity check

# %%
import unittest
import test
suite = unittest.TestLoader().loadTestsFromModule(test)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# <unittest.runner.TextTestResult run=0 errors=0 failures=0>

# %% [markdown]
# ## Experiments

# %%
@dataclass
class Arguments:
  # Data
  batch_size: int = 128
  # Model
  model: str = 'mlp'  # [mlp, resnet18, mlpmixer]
  model_config: str = "./model_configs/mlp.json" # path to model config json file

  # Optimization
  optimizer: str = 'adamw'  # [sgd, momentum, adam, adamw]
  epochs: int = 15
  lr: float = 1e-3
  momentum: float = 0.9
  weight_decay: float = 5e-4

  # Experiment
  logdir: str = '/content/assignment/logs'
  seed: int = 42

  # Miscellaneous
  device: str = 'cuda'
  visualize : bool = False
  print_every: int = 80

# %%
# Main code entry. Train the model and save the logs
from main import train, evaluate
def main_entry(args):
    # Check for the device
    if (args.device == "cuda") and not torch.cuda.is_available():
        warnings.warn(
            "CUDA is not available, make that your environment is "
            "running on GPU (e.g. in the Notebook Settings in Google Colab). "
            'Forcing device="cpu".'
        )
        args.device = "cpu"

    if args.device == "cpu":
        warnings.warn(
            "You are about to run on CPU, and might run out of memory "
            "shortly. You can try setting batch_size=1 to reduce memory usage."
        )

    # Seed the experiment, for repeatability
    seed_experiment(args.seed)

    test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize([0.49139968, 0.48215841, 0.44653091], [0.24703223, 0.24348513, 0.26158784])
                                     ])
    # For training, we add some augmentation. Networks are too powerful and would overfit.
    train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                          transforms.RandomResizedCrop((32,32),scale=(0.8,1.0),ratio=(0.9,1.1)),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.49139968, 0.48215841, 0.44653091], [0.24703223, 0.24348513, 0.26158784])
                                        ])
    # Loading the training dataset. We need to split it into a training and validation part
    # We need to do a little trick because the validation set should not use the augmentation.
    train_dataset = CIFAR10(root='./data', train=True, transform=train_transform, download=True)
    val_dataset = CIFAR10(root='./data', train=True, transform=test_transform, download=True)
    train_set, _ = torch.utils.data.random_split(train_dataset, [45000, 5000])
    _, val_set = torch.utils.data.random_split(val_dataset, [45000, 5000])

    # Loading the test set
    test_set = CIFAR10(root='./data', train=False, transform=test_transform, download=True)
    
    # Load model
    print(f'Build model {args.model.upper()}...')
    if args.model_config is not None:
        print(f'Loading model config from {args.model_config}')
        with open(args.model_config) as f:
            model_config = json.load(f)
    else:
        raise ValueError('Please provide a model config json')
    print(f'########## {args.model.upper()} CONFIG ################')
    for key, val in model_config.items():
        print(f'{key}:\t{val}')
    print('############################################')
    model_cls = {'mlp': MLP, 'resnet18': ResNet18, 'mlpmixer': MLPMixer}[args.model]
    model = model_cls(**model_config)
    model.to(args.device)
    
    # Optimizer
    if args.optimizer == "adamw":
        optimizer = optim.AdamW(
            model.parameters(), lr=args.lr, weight_decay=args.weight_decay
        )
    elif args.optimizer == "adam":
        optimizer = optim.Adam(model.parameters(), lr=args.lr)
    elif args.optimizer == "sgd":
        optimizer = optim.SGD(
            model.parameters(), lr=args.lr, weight_decay=args.weight_decay
        )
    elif args.optimizer == "momentum":
        optimizer = optim.SGD(
            model.parameters(),
            lr=args.lr,
            momentum=args.momentum,
            weight_decay=args.weight_decay,
        )
    
    print(
        f"Initialized {args.model.upper()} model with {sum(p.numel() for p in model.parameters())} "
        f"total parameters, of which {sum(p.numel() for p in model.parameters() if p.requires_grad)} are learnable."
    )

    train_losses, valid_losses = [], []
    train_accs, valid_accs = [], []
    train_times, valid_times = [], []
    
    # We define a set of data loaders that we can use for various purposes later.
    train_dataloader = DataLoader(train_set, batch_size=args.batch_size, shuffle=True, drop_last=True, pin_memory=True, num_workers=4)
    valid_dataloader = DataLoader(val_set, batch_size=args.batch_size, shuffle=False, drop_last=False, num_workers=4)
    test_dataloader = DataLoader(test_set, batch_size=args.batch_size, shuffle=False, drop_last=False, num_workers=4)
    for epoch in range(args.epochs):
        tqdm.write(f"====== Epoch {epoch} ======>")
        loss, acc, wall_time = train(epoch, model, train_dataloader, optimizer,args)
        train_losses.append(loss)
        train_accs.append(acc)
        train_times.append(wall_time)

        loss, acc, wall_time = evaluate(epoch, model, valid_dataloader,args)
        valid_losses.append(loss)
        valid_accs.append(acc)
        valid_times.append(wall_time)
        
    test_loss, test_acc, test_time = evaluate(
        epoch, model, test_dataloader, args, mode="test"
    )
    print(f"===== Best validation Accuracy: {max(valid_accs):.3f} =====>")
    # Save log if logdir provided
    if args.logdir is not None:
        print(f'Writing training logs to {args.logdir}...')
        os.makedirs(args.logdir, exist_ok=True)
        with open(os.path.join(args.logdir, 'results.json'), 'w') as f:
            f.write(json.dumps(
                {
                    "train_losses": train_losses,
                    "valid_losses": valid_losses,
                    "train_accs": train_accs,
                    "valid_accs": valid_accs,
                    "test_loss": test_loss,
                    "test_acc": test_acc
                },
                indent=4,
            ))
    
        # Visualize
        if args.visualize and args.model in ['resnet18', 'mlpmixer']:
            model.visualize(args.logdir)
    return max(valid_accs),max(train_accs)

# %%
# MLP with 15 epochs
conf={
    "input_size": 3072,
    "hidden_sizes": [1024, 512, 64, 64],
    "num_classes": 10,
    "activation": "tanh"
}
with open("json_object.json", "w") as outfile:
    json.dump(conf, outfile)
config = Arguments(model='mlp', 
                   model_config='json_object.json', 
                   epochs=15)
main_entry(config)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model MLP...
# Loading model config from json_object.json
# ########## MLP CONFIG ################
# input_size:	3072
# hidden_sizes:	[1024, 512, 64, 64]
# num_classes:	10
# activation:	tanh
# ############################################
# Initialized MLP model with 3709194 total parameters, of which 3709194 are learnable.
# ====== Epoch 0 ======>
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.36526
# [TRAIN] Epoch: 0, Iter: 80, Loss: 1.76098
# [TRAIN] Epoch: 0, Iter: 160, Loss: 2.03063
# [TRAIN] Epoch: 0, Iter: 240, Loss: 1.75019
# [TRAIN] Epoch: 0, Iter: 320, Loss: 1.65412
# == [TRAIN] Epoch: 0, Accuracy: 0.343 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: 1.84551
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.398 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: 1.69707
# [TRAIN] Epoch: 1, Iter: 80, Loss: 1.79264
# [TRAIN] Epoch: 1, Iter: 160, Loss: 1.86942
# [TRAIN] Epoch: 1, Iter: 240, Loss: 1.72706
# [TRAIN] Epoch: 1, Iter: 320, Loss: 1.75249
# == [TRAIN] Epoch: 1, Accuracy: 0.388 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: 1.72588
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.407 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: 1.66756
# [TRAIN] Epoch: 2, Iter: 80, Loss: 1.69218
# [TRAIN] Epoch: 2, Iter: 160, Loss: 1.72585
# [TRAIN] Epoch: 2, Iter: 240, Loss: 1.77968
# [TRAIN] Epoch: 2, Iter: 320, Loss: 1.70373
# == [TRAIN] Epoch: 2, Accuracy: 0.403 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: 1.73310
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.414 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: 1.67889
# [TRAIN] Epoch: 3, Iter: 80, Loss: 1.65779
# [TRAIN] Epoch: 3, Iter: 160, Loss: 1.90011
# [TRAIN] Epoch: 3, Iter: 240, Loss: 1.67565
# [TRAIN] Epoch: 3, Iter: 320, Loss: 1.55994
# == [TRAIN] Epoch: 3, Accuracy: 0.416 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: 1.65700
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.443 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: 1.79048
# [TRAIN] Epoch: 4, Iter: 80, Loss: 1.62476
# [TRAIN] Epoch: 4, Iter: 160, Loss: 1.55251
# [TRAIN] Epoch: 4, Iter: 240, Loss: 1.59684
# [TRAIN] Epoch: 4, Iter: 320, Loss: 1.66295
# == [TRAIN] Epoch: 4, Accuracy: 0.423 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: 1.62110
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.435 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: 1.72530
# [TRAIN] Epoch: 5, Iter: 80, Loss: 1.67605
# [TRAIN] Epoch: 5, Iter: 160, Loss: 1.47448
# [TRAIN] Epoch: 5, Iter: 240, Loss: 1.54515
# [TRAIN] Epoch: 5, Iter: 320, Loss: 1.66783
# == [TRAIN] Epoch: 5, Accuracy: 0.431 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: 1.60107
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.449 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: 1.58040
# [TRAIN] Epoch: 6, Iter: 80, Loss: 1.61144
# [TRAIN] Epoch: 6, Iter: 160, Loss: 1.62426
# [TRAIN] Epoch: 6, Iter: 240, Loss: 1.61715
# [TRAIN] Epoch: 6, Iter: 320, Loss: 1.62930
# == [TRAIN] Epoch: 6, Accuracy: 0.434 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: 1.60770
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.446 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: 1.58720
# [TRAIN] Epoch: 7, Iter: 80, Loss: 1.59047
# [TRAIN] Epoch: 7, Iter: 160, Loss: 1.56778
# [TRAIN] Epoch: 7, Iter: 240, Loss: 1.32748
# [TRAIN] Epoch: 7, Iter: 320, Loss: 1.68771
# == [TRAIN] Epoch: 7, Accuracy: 0.441 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: 1.59984
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.468 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: 1.45486
# [TRAIN] Epoch: 8, Iter: 80, Loss: 1.61209
# [TRAIN] Epoch: 8, Iter: 160, Loss: 1.50168
# [TRAIN] Epoch: 8, Iter: 240, Loss: 1.61532
# [TRAIN] Epoch: 8, Iter: 320, Loss: 1.61740
# == [TRAIN] Epoch: 8, Accuracy: 0.439 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: 1.64717
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.463 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: 1.43077
# [TRAIN] Epoch: 9, Iter: 80, Loss: 1.57450
# [TRAIN] Epoch: 9, Iter: 160, Loss: 1.38522
# [TRAIN] Epoch: 9, Iter: 240, Loss: 1.55079
# [TRAIN] Epoch: 9, Iter: 320, Loss: 1.57055
# == [TRAIN] Epoch: 9, Accuracy: 0.445 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: 1.60028
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.465 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: 1.41528
# [TRAIN] Epoch: 10, Iter: 80, Loss: 1.64370
# [TRAIN] Epoch: 10, Iter: 160, Loss: 1.50698
# [TRAIN] Epoch: 10, Iter: 240, Loss: 1.42581
# [TRAIN] Epoch: 10, Iter: 320, Loss: 1.56777
# == [TRAIN] Epoch: 10, Accuracy: 0.449 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: 1.54997
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.463 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: 1.61232
# [TRAIN] Epoch: 11, Iter: 80, Loss: 1.53322
# [TRAIN] Epoch: 11, Iter: 160, Loss: 1.56695
# [TRAIN] Epoch: 11, Iter: 240, Loss: 1.63385
# [TRAIN] Epoch: 11, Iter: 320, Loss: 1.41683
# == [TRAIN] Epoch: 11, Accuracy: 0.452 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: 1.58792
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.449 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: 1.43704
# [TRAIN] Epoch: 12, Iter: 80, Loss: 1.69518
# [TRAIN] Epoch: 12, Iter: 160, Loss: 1.46733
# [TRAIN] Epoch: 12, Iter: 240, Loss: 1.62463
# [TRAIN] Epoch: 12, Iter: 320, Loss: 1.49048
# == [TRAIN] Epoch: 12, Accuracy: 0.454 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: 1.59127
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.463 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: 1.42691
# [TRAIN] Epoch: 13, Iter: 80, Loss: 1.73776
# [TRAIN] Epoch: 13, Iter: 160, Loss: 1.43059
# [TRAIN] Epoch: 13, Iter: 240, Loss: 1.47703
# [TRAIN] Epoch: 13, Iter: 320, Loss: 1.65667
# == [TRAIN] Epoch: 13, Accuracy: 0.460 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: 1.57082
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.467 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: 1.56975
# [TRAIN] Epoch: 14, Iter: 80, Loss: 1.58270
# [TRAIN] Epoch: 14, Iter: 160, Loss: 1.34426
# [TRAIN] Epoch: 14, Iter: 240, Loss: 1.50707
# [TRAIN] Epoch: 14, Iter: 320, Loss: 1.60171
# == [TRAIN] Epoch: 14, Accuracy: 0.463 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: 1.55848
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.473 ===>
# [TEST] Epoch: 14, Iter: 0, Loss: 1.41977
# === [TEST] Epoch: 14, Iter: 78, Accuracy: 0.452 ===>
# ===== Best validation Accuracy: 0.473 =====>
# Writing training logs to exps/mlp_tanh...

# %%
with open('/content/exps/mlp_relu/results.json') as json_file:
    data = json.load(json_file)

# %%
k=['/content/exps/mlp_relu','/content/exps/mlp_tanh','/content/exps/mlp_sigmoid']
z=['relu','tanh','sigmoid']

# %%
generate_plots(list_of_dirs=k,legend_names=z,save_path='/content/exps/images')

# %%
# Resnet with 15 epochs
conf={
    "num_classes": 10
}
with open("json_object.json", "w") as outfile:    json.dump(conf, outfile)
lr = [0.1, 0.01, 0.001, 0.0001, 0.00001]
for i in range(0,len(lr)):
  config = Arguments(model='resnet18', 
                    model_config='json_object.json', 
                    epochs=15,lr=lr[i], logdir="exps/resnet18_"+str(lr[i]))
  main_entry(config)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model RESNET18...
# Loading model config from json_object.json
# ########## RESNET18 CONFIG ################
# num_classes:	10
# ############################################
# Initialized RESNET18 model with 11173962 total parameters, of which 11173962 are learnable.
# ====== Epoch 0 ======>
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.35367
# [TRAIN] Epoch: 0, Iter: 80, Loss: nan
# [TRAIN] Epoch: 0, Iter: 160, Loss: nan
# [TRAIN] Epoch: 0, Iter: 240, Loss: nan
# [TRAIN] Epoch: 0, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 0, Accuracy: 0.100 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: nan
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: nan
# [TRAIN] Epoch: 1, Iter: 80, Loss: nan
# [TRAIN] Epoch: 1, Iter: 160, Loss: nan
# [TRAIN] Epoch: 1, Iter: 240, Loss: nan
# [TRAIN] Epoch: 1, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 1, Accuracy: 0.100 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: nan
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: nan
# [TRAIN] Epoch: 2, Iter: 80, Loss: nan
# [TRAIN] Epoch: 2, Iter: 160, Loss: nan
# [TRAIN] Epoch: 2, Iter: 240, Loss: nan
# [TRAIN] Epoch: 2, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 2, Accuracy: 0.100 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: nan
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: nan
# [TRAIN] Epoch: 3, Iter: 80, Loss: nan
# [TRAIN] Epoch: 3, Iter: 160, Loss: nan
# [TRAIN] Epoch: 3, Iter: 240, Loss: nan
# [TRAIN] Epoch: 3, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 3, Accuracy: 0.100 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: nan
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: nan
# [TRAIN] Epoch: 4, Iter: 80, Loss: nan
# [TRAIN] Epoch: 4, Iter: 160, Loss: nan
# [TRAIN] Epoch: 4, Iter: 240, Loss: nan
# [TRAIN] Epoch: 4, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 4, Accuracy: 0.100 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: nan
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: nan
# [TRAIN] Epoch: 5, Iter: 80, Loss: nan
# [TRAIN] Epoch: 5, Iter: 160, Loss: nan
# [TRAIN] Epoch: 5, Iter: 240, Loss: nan
# [TRAIN] Epoch: 5, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 5, Accuracy: 0.100 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: nan
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: nan
# [TRAIN] Epoch: 6, Iter: 80, Loss: nan
# [TRAIN] Epoch: 6, Iter: 160, Loss: nan
# [TRAIN] Epoch: 6, Iter: 240, Loss: nan
# [TRAIN] Epoch: 6, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 6, Accuracy: 0.100 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: nan
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: nan
# [TRAIN] Epoch: 7, Iter: 80, Loss: nan
# [TRAIN] Epoch: 7, Iter: 160, Loss: nan
# [TRAIN] Epoch: 7, Iter: 240, Loss: nan
# [TRAIN] Epoch: 7, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 7, Accuracy: 0.100 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: nan
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: nan
# [TRAIN] Epoch: 8, Iter: 80, Loss: nan
# [TRAIN] Epoch: 8, Iter: 160, Loss: nan
# [TRAIN] Epoch: 8, Iter: 240, Loss: nan
# [TRAIN] Epoch: 8, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 8, Accuracy: 0.100 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: nan
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: nan
# [TRAIN] Epoch: 9, Iter: 80, Loss: nan
# [TRAIN] Epoch: 9, Iter: 160, Loss: nan
# [TRAIN] Epoch: 9, Iter: 240, Loss: nan
# [TRAIN] Epoch: 9, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 9, Accuracy: 0.100 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: nan
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: nan
# [TRAIN] Epoch: 10, Iter: 80, Loss: nan
# [TRAIN] Epoch: 10, Iter: 160, Loss: nan
# [TRAIN] Epoch: 10, Iter: 240, Loss: nan
# [TRAIN] Epoch: 10, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 10, Accuracy: 0.100 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: nan
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: nan
# [TRAIN] Epoch: 11, Iter: 80, Loss: nan
# [TRAIN] Epoch: 11, Iter: 160, Loss: nan
# [TRAIN] Epoch: 11, Iter: 240, Loss: nan
# [TRAIN] Epoch: 11, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 11, Accuracy: 0.100 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: nan
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: nan
# [TRAIN] Epoch: 12, Iter: 80, Loss: nan
# [TRAIN] Epoch: 12, Iter: 160, Loss: nan
# [TRAIN] Epoch: 12, Iter: 240, Loss: nan
# [TRAIN] Epoch: 12, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 12, Accuracy: 0.100 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: nan
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: nan
# [TRAIN] Epoch: 13, Iter: 80, Loss: nan
# [TRAIN] Epoch: 13, Iter: 160, Loss: nan
# [TRAIN] Epoch: 13, Iter: 240, Loss: nan
# [TRAIN] Epoch: 13, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 13, Accuracy: 0.100 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: nan
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: nan
# [TRAIN] Epoch: 14, Iter: 80, Loss: nan
# [TRAIN] Epoch: 14, Iter: 160, Loss: nan
# [TRAIN] Epoch: 14, Iter: 240, Loss: nan
# [TRAIN] Epoch: 14, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 14, Accuracy: 0.100 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: nan
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.103 ===>
# [TEST] Epoch: 14, Iter: 0, Loss: nan
# === [TEST] Epoch: 14, Iter: 78, Accuracy: 0.100 ===>
# ===== Best validation Accuracy: 0.103 =====>
# Writing training logs to exps/resnet18_0.1...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model RESNET18...
# Loading model config from json_object.json
# ########## RESNET18 CONFIG ################
# num_classes:	10
# ############################################
# Initialized RESNET18 model with 11173962 total parameters, of which 11173962 are learnable.
# ====== Epoch 0 ======>
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.35367
# [TRAIN] Epoch: 0, Iter: 80, Loss: nan
# [TRAIN] Epoch: 0, Iter: 160, Loss: nan
# [TRAIN] Epoch: 0, Iter: 240, Loss: nan
# [TRAIN] Epoch: 0, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 0, Accuracy: 0.100 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: nan
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: nan
# [TRAIN] Epoch: 1, Iter: 80, Loss: nan
# [TRAIN] Epoch: 1, Iter: 160, Loss: nan
# [TRAIN] Epoch: 1, Iter: 240, Loss: nan
# [TRAIN] Epoch: 1, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 1, Accuracy: 0.100 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: nan
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: nan
# [TRAIN] Epoch: 2, Iter: 80, Loss: nan
# [TRAIN] Epoch: 2, Iter: 160, Loss: nan
# [TRAIN] Epoch: 2, Iter: 240, Loss: nan
# [TRAIN] Epoch: 2, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 2, Accuracy: 0.100 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: nan
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: nan
# [TRAIN] Epoch: 3, Iter: 80, Loss: nan
# [TRAIN] Epoch: 3, Iter: 160, Loss: nan
# [TRAIN] Epoch: 3, Iter: 240, Loss: nan
# [TRAIN] Epoch: 3, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 3, Accuracy: 0.100 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: nan
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: nan
# [TRAIN] Epoch: 4, Iter: 80, Loss: nan
# [TRAIN] Epoch: 4, Iter: 160, Loss: nan
# [TRAIN] Epoch: 4, Iter: 240, Loss: nan
# [TRAIN] Epoch: 4, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 4, Accuracy: 0.100 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: nan
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: nan
# [TRAIN] Epoch: 5, Iter: 80, Loss: nan
# [TRAIN] Epoch: 5, Iter: 160, Loss: nan
# [TRAIN] Epoch: 5, Iter: 240, Loss: nan
# [TRAIN] Epoch: 5, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 5, Accuracy: 0.100 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: nan
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: nan
# [TRAIN] Epoch: 6, Iter: 80, Loss: nan
# [TRAIN] Epoch: 6, Iter: 160, Loss: nan
# [TRAIN] Epoch: 6, Iter: 240, Loss: nan
# [TRAIN] Epoch: 6, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 6, Accuracy: 0.100 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: nan
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: nan
# [TRAIN] Epoch: 7, Iter: 80, Loss: nan
# [TRAIN] Epoch: 7, Iter: 160, Loss: nan
# [TRAIN] Epoch: 7, Iter: 240, Loss: nan
# [TRAIN] Epoch: 7, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 7, Accuracy: 0.100 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: nan
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: nan
# [TRAIN] Epoch: 8, Iter: 80, Loss: nan
# [TRAIN] Epoch: 8, Iter: 160, Loss: nan
# [TRAIN] Epoch: 8, Iter: 240, Loss: nan
# [TRAIN] Epoch: 8, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 8, Accuracy: 0.100 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: nan
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: nan
# [TRAIN] Epoch: 9, Iter: 80, Loss: nan
# [TRAIN] Epoch: 9, Iter: 160, Loss: nan
# [TRAIN] Epoch: 9, Iter: 240, Loss: nan
# [TRAIN] Epoch: 9, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 9, Accuracy: 0.100 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: nan
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: nan
# [TRAIN] Epoch: 10, Iter: 80, Loss: nan
# [TRAIN] Epoch: 10, Iter: 160, Loss: nan
# [TRAIN] Epoch: 10, Iter: 240, Loss: nan
# [TRAIN] Epoch: 10, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 10, Accuracy: 0.100 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: nan
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: nan
# [TRAIN] Epoch: 11, Iter: 80, Loss: nan
# [TRAIN] Epoch: 11, Iter: 160, Loss: nan
# [TRAIN] Epoch: 11, Iter: 240, Loss: nan
# [TRAIN] Epoch: 11, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 11, Accuracy: 0.100 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: nan
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: nan
# [TRAIN] Epoch: 12, Iter: 80, Loss: nan
# [TRAIN] Epoch: 12, Iter: 160, Loss: nan
# [TRAIN] Epoch: 12, Iter: 240, Loss: nan
# [TRAIN] Epoch: 12, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 12, Accuracy: 0.100 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: nan
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: nan
# [TRAIN] Epoch: 13, Iter: 80, Loss: nan
# [TRAIN] Epoch: 13, Iter: 160, Loss: nan
# [TRAIN] Epoch: 13, Iter: 240, Loss: nan
# [TRAIN] Epoch: 13, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 13, Accuracy: 0.100 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: nan
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.103 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: nan
# [TRAIN] Epoch: 14, Iter: 80, Loss: nan
# [TRAIN] Epoch: 14, Iter: 160, Loss: nan
# [TRAIN] Epoch: 14, Iter: 240, Loss: nan
# [TRAIN] Epoch: 14, Iter: 320, Loss: nan
# == [TRAIN] Epoch: 14, Accuracy: 0.100 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: nan
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.103 ===>
# [TEST] Epoch: 14, Iter: 0, Loss: nan
# === [TEST] Epoch: 14, Iter: 78, Accuracy: 0.100 ===>
# ===== Best validation Accuracy: 0.103 =====>
# Writing training logs to exps/resnet18_0.01...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model RESNET18...
# Loading model config from json_object.json
# ########## RESNET18 CONFIG ################
# num_classes:	10
# ############################################
# Initialized RESNET18 model with 11173962 total parameters, of which 11173962 are learnable.
# ====== Epoch 0 ======>
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.35367
# [TRAIN] Epoch: 0, Iter: 80, Loss: 1.52730
# [TRAIN] Epoch: 0, Iter: 160, Loss: 1.50748
# [TRAIN] Epoch: 0, Iter: 240, Loss: 1.39050
# [TRAIN] Epoch: 0, Iter: 320, Loss: 1.24121
# == [TRAIN] Epoch: 0, Accuracy: 0.468 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: 1.24331
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.581 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: 1.00828
# [TRAIN] Epoch: 1, Iter: 80, Loss: 0.93546
# [TRAIN] Epoch: 1, Iter: 160, Loss: 0.98669
# [TRAIN] Epoch: 1, Iter: 240, Loss: 1.00420
# [TRAIN] Epoch: 1, Iter: 320, Loss: 0.83634
# == [TRAIN] Epoch: 1, Accuracy: 0.656 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: 0.92905
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.675 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: 0.98228
# [TRAIN] Epoch: 2, Iter: 80, Loss: 0.71992
# [TRAIN] Epoch: 2, Iter: 160, Loss: 0.78637
# [TRAIN] Epoch: 2, Iter: 240, Loss: 0.81686
# [TRAIN] Epoch: 2, Iter: 320, Loss: 0.66338
# == [TRAIN] Epoch: 2, Accuracy: 0.739 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: 0.86966
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.700 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: 0.65708
# [TRAIN] Epoch: 3, Iter: 80, Loss: 0.63978
# [TRAIN] Epoch: 3, Iter: 160, Loss: 0.64207
# [TRAIN] Epoch: 3, Iter: 240, Loss: 0.50185
# [TRAIN] Epoch: 3, Iter: 320, Loss: 0.72408
# == [TRAIN] Epoch: 3, Accuracy: 0.784 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: 0.92448
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.746 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: 0.55846
# [TRAIN] Epoch: 4, Iter: 80, Loss: 0.60718
# [TRAIN] Epoch: 4, Iter: 160, Loss: 0.64510
# [TRAIN] Epoch: 4, Iter: 240, Loss: 0.49706
# [TRAIN] Epoch: 4, Iter: 320, Loss: 0.46979
# == [TRAIN] Epoch: 4, Accuracy: 0.812 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: 0.45849
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.836 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: 0.39221
# [TRAIN] Epoch: 5, Iter: 80, Loss: 0.42563
# [TRAIN] Epoch: 5, Iter: 160, Loss: 0.54417
# [TRAIN] Epoch: 5, Iter: 240, Loss: 0.47995
# [TRAIN] Epoch: 5, Iter: 320, Loss: 0.25989
# == [TRAIN] Epoch: 5, Accuracy: 0.834 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: 0.50033
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.830 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: 0.50675
# [TRAIN] Epoch: 6, Iter: 80, Loss: 0.46340
# [TRAIN] Epoch: 6, Iter: 160, Loss: 0.33975
# [TRAIN] Epoch: 6, Iter: 240, Loss: 0.43576
# [TRAIN] Epoch: 6, Iter: 320, Loss: 0.23879
# == [TRAIN] Epoch: 6, Accuracy: 0.851 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: 0.49404
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.846 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: 0.31644
# [TRAIN] Epoch: 7, Iter: 80, Loss: 0.34353
# [TRAIN] Epoch: 7, Iter: 160, Loss: 0.32053
# [TRAIN] Epoch: 7, Iter: 240, Loss: 0.39475
# [TRAIN] Epoch: 7, Iter: 320, Loss: 0.37629
# == [TRAIN] Epoch: 7, Accuracy: 0.866 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: 0.41695
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.868 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: 0.40152
# [TRAIN] Epoch: 8, Iter: 80, Loss: 0.27134
# [TRAIN] Epoch: 8, Iter: 160, Loss: 0.24189
# [TRAIN] Epoch: 8, Iter: 240, Loss: 0.38522
# [TRAIN] Epoch: 8, Iter: 320, Loss: 0.47631
# == [TRAIN] Epoch: 8, Accuracy: 0.874 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: 0.34161
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.879 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: 0.32817
# [TRAIN] Epoch: 9, Iter: 80, Loss: 0.39533
# [TRAIN] Epoch: 9, Iter: 160, Loss: 0.46653
# [TRAIN] Epoch: 9, Iter: 240, Loss: 0.47205
# [TRAIN] Epoch: 9, Iter: 320, Loss: 0.35318
# == [TRAIN] Epoch: 9, Accuracy: 0.888 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: 0.23769
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.909 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: 0.23035
# [TRAIN] Epoch: 10, Iter: 80, Loss: 0.37590
# [TRAIN] Epoch: 10, Iter: 160, Loss: 0.36372
# [TRAIN] Epoch: 10, Iter: 240, Loss: 0.35360
# [TRAIN] Epoch: 10, Iter: 320, Loss: 0.26286
# == [TRAIN] Epoch: 10, Accuracy: 0.898 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: 0.32048
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.903 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: 0.18240
# [TRAIN] Epoch: 11, Iter: 80, Loss: 0.27007
# [TRAIN] Epoch: 11, Iter: 160, Loss: 0.23491
# [TRAIN] Epoch: 11, Iter: 240, Loss: 0.25448
# [TRAIN] Epoch: 11, Iter: 320, Loss: 0.43739
# == [TRAIN] Epoch: 11, Accuracy: 0.906 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: 0.32310
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.871 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: 0.29407
# [TRAIN] Epoch: 12, Iter: 80, Loss: 0.16007
# [TRAIN] Epoch: 12, Iter: 160, Loss: 0.28622
# [TRAIN] Epoch: 12, Iter: 240, Loss: 0.19294
# [TRAIN] Epoch: 12, Iter: 320, Loss: 0.29360
# == [TRAIN] Epoch: 12, Accuracy: 0.911 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: 0.26201
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.925 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: 0.25009
# [TRAIN] Epoch: 13, Iter: 80, Loss: 0.26695
# [TRAIN] Epoch: 13, Iter: 160, Loss: 0.25696
# [TRAIN] Epoch: 13, Iter: 240, Loss: 0.25055
# [TRAIN] Epoch: 13, Iter: 320, Loss: 0.24818
# == [TRAIN] Epoch: 13, Accuracy: 0.919 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: 0.24076
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.926 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: 0.21072
# [TRAIN] Epoch: 14, Iter: 80, Loss: 0.33071
# [TRAIN] Epoch: 14, Iter: 160, Loss: 0.37177
# [TRAIN] Epoch: 14, Iter: 240, Loss: 0.19500
# [TRAIN] Epoch: 14, Iter: 320, Loss: 0.20223
# == [TRAIN] Epoch: 14, Accuracy: 0.925 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: 0.27205
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.938 ===>
# [TEST] Epoch: 14, Iter: 0, Loss: 0.36075
# === [TEST] Epoch: 14, Iter: 78, Accuracy: 0.872 ===>
# ===== Best validation Accuracy: 0.938 =====>
# Writing training logs to exps/resnet18_0.001...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model RESNET18...
# Loading model config from json_object.json
# ########## RESNET18 CONFIG ################
# num_classes:	10
# ############################################
# Initialized RESNET18 model with 11173962 total parameters, of which 11173962 are learnable.
# ====== Epoch 0 ======>
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.35367
# [TRAIN] Epoch: 0, Iter: 80, Loss: 1.45763
# [TRAIN] Epoch: 0, Iter: 160, Loss: 1.53011
# [TRAIN] Epoch: 0, Iter: 240, Loss: 1.21798
# [TRAIN] Epoch: 0, Iter: 320, Loss: 1.07192
# == [TRAIN] Epoch: 0, Accuracy: 0.510 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: 1.14955
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.611 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: 0.93590
# [TRAIN] Epoch: 1, Iter: 80, Loss: 0.90102
# [TRAIN] Epoch: 1, Iter: 160, Loss: 0.93388
# [TRAIN] Epoch: 1, Iter: 240, Loss: 0.92820
# [TRAIN] Epoch: 1, Iter: 320, Loss: 0.69488
# == [TRAIN] Epoch: 1, Accuracy: 0.669 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: 0.95875
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.682 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: 0.93753
# [TRAIN] Epoch: 2, Iter: 80, Loss: 0.70761
# [TRAIN] Epoch: 2, Iter: 160, Loss: 0.81755
# [TRAIN] Epoch: 2, Iter: 240, Loss: 0.77050
# [TRAIN] Epoch: 2, Iter: 320, Loss: 0.67822
# == [TRAIN] Epoch: 2, Accuracy: 0.740 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: 0.79795
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.730 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: 0.66743
# [TRAIN] Epoch: 3, Iter: 80, Loss: 0.52314
# [TRAIN] Epoch: 3, Iter: 160, Loss: 0.68539
# [TRAIN] Epoch: 3, Iter: 240, Loss: 0.57309
# [TRAIN] Epoch: 3, Iter: 320, Loss: 0.66462
# == [TRAIN] Epoch: 3, Accuracy: 0.785 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: 0.56751
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.799 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: 0.52481
# [TRAIN] Epoch: 4, Iter: 80, Loss: 0.57312
# [TRAIN] Epoch: 4, Iter: 160, Loss: 0.53956
# [TRAIN] Epoch: 4, Iter: 240, Loss: 0.48351
# [TRAIN] Epoch: 4, Iter: 320, Loss: 0.48600
# == [TRAIN] Epoch: 4, Accuracy: 0.811 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: 0.48398
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.819 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: 0.44908
# [TRAIN] Epoch: 5, Iter: 80, Loss: 0.34386
# [TRAIN] Epoch: 5, Iter: 160, Loss: 0.50958
# [TRAIN] Epoch: 5, Iter: 240, Loss: 0.51496
# [TRAIN] Epoch: 5, Iter: 320, Loss: 0.41151
# == [TRAIN] Epoch: 5, Accuracy: 0.831 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: 0.39323
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.849 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: 0.50398
# [TRAIN] Epoch: 6, Iter: 80, Loss: 0.40483
# [TRAIN] Epoch: 6, Iter: 160, Loss: 0.41460
# [TRAIN] Epoch: 6, Iter: 240, Loss: 0.46630
# [TRAIN] Epoch: 6, Iter: 320, Loss: 0.28333
# == [TRAIN] Epoch: 6, Accuracy: 0.848 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: 0.43933
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.844 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: 0.38378
# [TRAIN] Epoch: 7, Iter: 80, Loss: 0.41414
# [TRAIN] Epoch: 7, Iter: 160, Loss: 0.35979
# [TRAIN] Epoch: 7, Iter: 240, Loss: 0.40344
# [TRAIN] Epoch: 7, Iter: 320, Loss: 0.37735
# == [TRAIN] Epoch: 7, Accuracy: 0.863 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: 0.42171
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.848 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: 0.44566
# [TRAIN] Epoch: 8, Iter: 80, Loss: 0.31534
# [TRAIN] Epoch: 8, Iter: 160, Loss: 0.34146
# [TRAIN] Epoch: 8, Iter: 240, Loss: 0.41866
# [TRAIN] Epoch: 8, Iter: 320, Loss: 0.35718
# == [TRAIN] Epoch: 8, Accuracy: 0.875 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: 0.33289
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.880 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: 0.25749
# [TRAIN] Epoch: 9, Iter: 80, Loss: 0.44322
# [TRAIN] Epoch: 9, Iter: 160, Loss: 0.45165
# [TRAIN] Epoch: 9, Iter: 240, Loss: 0.45412
# [TRAIN] Epoch: 9, Iter: 320, Loss: 0.34520
# == [TRAIN] Epoch: 9, Accuracy: 0.888 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: 0.26334
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.856 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: 0.23364
# [TRAIN] Epoch: 10, Iter: 80, Loss: 0.30291
# [TRAIN] Epoch: 10, Iter: 160, Loss: 0.36668
# [TRAIN] Epoch: 10, Iter: 240, Loss: 0.35407
# [TRAIN] Epoch: 10, Iter: 320, Loss: 0.26775
# == [TRAIN] Epoch: 10, Accuracy: 0.897 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: 0.30717
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.904 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: 0.28175
# [TRAIN] Epoch: 11, Iter: 80, Loss: 0.24656
# [TRAIN] Epoch: 11, Iter: 160, Loss: 0.32459
# [TRAIN] Epoch: 11, Iter: 240, Loss: 0.22717
# [TRAIN] Epoch: 11, Iter: 320, Loss: 0.34663
# == [TRAIN] Epoch: 11, Accuracy: 0.908 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: 0.36855
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.877 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: 0.21161
# [TRAIN] Epoch: 12, Iter: 80, Loss: 0.22248
# [TRAIN] Epoch: 12, Iter: 160, Loss: 0.23403
# [TRAIN] Epoch: 12, Iter: 240, Loss: 0.25792
# [TRAIN] Epoch: 12, Iter: 320, Loss: 0.27483
# == [TRAIN] Epoch: 12, Accuracy: 0.915 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: 0.26277
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.930 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: 0.21957
# [TRAIN] Epoch: 13, Iter: 80, Loss: 0.22039
# [TRAIN] Epoch: 13, Iter: 160, Loss: 0.24615
# [TRAIN] Epoch: 13, Iter: 240, Loss: 0.23141
# [TRAIN] Epoch: 13, Iter: 320, Loss: 0.22212
# == [TRAIN] Epoch: 13, Accuracy: 0.924 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: 0.27463
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.904 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: 0.20312
# [TRAIN] Epoch: 14, Iter: 80, Loss: 0.28895
# [TRAIN] Epoch: 14, Iter: 160, Loss: 0.26261
# [TRAIN] Epoch: 14, Iter: 240, Loss: 0.18125
# [TRAIN] Epoch: 14, Iter: 320, Loss: 0.13390
# == [TRAIN] Epoch: 14, Accuracy: 0.925 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: 0.24786
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.939 ===>
# [TEST] Epoch: 14, Iter: 0, Loss: 0.34966
# === [TEST] Epoch: 14, Iter: 78, Accuracy: 0.838 ===>
# ===== Best validation Accuracy: 0.939 =====>
# Writing training logs to exps/resnet18_0.0001...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model RESNET18...
# Loading model config from json_object.json
# ########## RESNET18 CONFIG ################
# num_classes:	10
# ############################################
# Initialized RESNET18 model with 11173962 total parameters, of which 11173962 are learnable.
# ====== Epoch 0 ======>
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.35367
# [TRAIN] Epoch: 0, Iter: 80, Loss: 1.73977
# [TRAIN] Epoch: 0, Iter: 160, Loss: 1.82865
# [TRAIN] Epoch: 0, Iter: 240, Loss: 1.53001
# [TRAIN] Epoch: 0, Iter: 320, Loss: 1.43099
# == [TRAIN] Epoch: 0, Accuracy: 0.375 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: 1.48579
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.472 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: 1.43968
# [TRAIN] Epoch: 1, Iter: 80, Loss: 1.34655
# [TRAIN] Epoch: 1, Iter: 160, Loss: 1.27626
# [TRAIN] Epoch: 1, Iter: 240, Loss: 1.34130
# [TRAIN] Epoch: 1, Iter: 320, Loss: 1.23329
# == [TRAIN] Epoch: 1, Accuracy: 0.506 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: 1.37643
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.533 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: 1.46948
# [TRAIN] Epoch: 2, Iter: 80, Loss: 1.31111
# [TRAIN] Epoch: 2, Iter: 160, Loss: 1.42393
# [TRAIN] Epoch: 2, Iter: 240, Loss: 1.24100
# [TRAIN] Epoch: 2, Iter: 320, Loss: 1.15014
# == [TRAIN] Epoch: 2, Accuracy: 0.555 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: 1.26415
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.585 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: 1.23657
# [TRAIN] Epoch: 3, Iter: 80, Loss: 1.08972
# [TRAIN] Epoch: 3, Iter: 160, Loss: 1.19038
# [TRAIN] Epoch: 3, Iter: 240, Loss: 1.06261
# [TRAIN] Epoch: 3, Iter: 320, Loss: 1.16411
# == [TRAIN] Epoch: 3, Accuracy: 0.593 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: 1.16740
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.614 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: 1.23919
# [TRAIN] Epoch: 4, Iter: 80, Loss: 1.11014
# [TRAIN] Epoch: 4, Iter: 160, Loss: 1.21269
# [TRAIN] Epoch: 4, Iter: 240, Loss: 1.07766
# [TRAIN] Epoch: 4, Iter: 320, Loss: 1.04663
# == [TRAIN] Epoch: 4, Accuracy: 0.622 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: 1.06491
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.653 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: 1.04160
# [TRAIN] Epoch: 5, Iter: 80, Loss: 0.93699
# [TRAIN] Epoch: 5, Iter: 160, Loss: 0.96087
# [TRAIN] Epoch: 5, Iter: 240, Loss: 1.13036
# [TRAIN] Epoch: 5, Iter: 320, Loss: 0.85996
# == [TRAIN] Epoch: 5, Accuracy: 0.642 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: 1.02646
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.669 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: 1.04413
# [TRAIN] Epoch: 6, Iter: 80, Loss: 1.00468
# [TRAIN] Epoch: 6, Iter: 160, Loss: 0.94773
# [TRAIN] Epoch: 6, Iter: 240, Loss: 1.06962
# [TRAIN] Epoch: 6, Iter: 320, Loss: 0.82333
# == [TRAIN] Epoch: 6, Accuracy: 0.665 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: 0.96155
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.693 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: 0.95182
# [TRAIN] Epoch: 7, Iter: 80, Loss: 1.00717
# [TRAIN] Epoch: 7, Iter: 160, Loss: 0.93144
# [TRAIN] Epoch: 7, Iter: 240, Loss: 0.89776
# [TRAIN] Epoch: 7, Iter: 320, Loss: 0.80300
# == [TRAIN] Epoch: 7, Accuracy: 0.682 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: 0.92214
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.695 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: 0.90228
# [TRAIN] Epoch: 8, Iter: 80, Loss: 0.89701
# [TRAIN] Epoch: 8, Iter: 160, Loss: 0.95429
# [TRAIN] Epoch: 8, Iter: 240, Loss: 0.95575
# [TRAIN] Epoch: 8, Iter: 320, Loss: 0.93080
# == [TRAIN] Epoch: 8, Accuracy: 0.697 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: 0.93984
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.708 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: 0.83805
# [TRAIN] Epoch: 9, Iter: 80, Loss: 0.90232
# [TRAIN] Epoch: 9, Iter: 160, Loss: 0.88324
# [TRAIN] Epoch: 9, Iter: 240, Loss: 0.76639
# [TRAIN] Epoch: 9, Iter: 320, Loss: 0.83674
# == [TRAIN] Epoch: 9, Accuracy: 0.709 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: 0.86379
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.744 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: 0.89787
# [TRAIN] Epoch: 10, Iter: 80, Loss: 0.82067
# [TRAIN] Epoch: 10, Iter: 160, Loss: 0.83542
# [TRAIN] Epoch: 10, Iter: 240, Loss: 0.87127
# [TRAIN] Epoch: 10, Iter: 320, Loss: 0.68785
# == [TRAIN] Epoch: 10, Accuracy: 0.725 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: 0.84177
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.747 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: 0.69785
# [TRAIN] Epoch: 11, Iter: 80, Loss: 0.67501
# [TRAIN] Epoch: 11, Iter: 160, Loss: 0.78061
# [TRAIN] Epoch: 11, Iter: 240, Loss: 0.73241
# [TRAIN] Epoch: 11, Iter: 320, Loss: 0.79173
# == [TRAIN] Epoch: 11, Accuracy: 0.735 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: 0.81381
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.757 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: 0.73197
# [TRAIN] Epoch: 12, Iter: 80, Loss: 0.76723
# [TRAIN] Epoch: 12, Iter: 160, Loss: 0.82957
# [TRAIN] Epoch: 12, Iter: 240, Loss: 0.76975
# [TRAIN] Epoch: 12, Iter: 320, Loss: 0.77038
# == [TRAIN] Epoch: 12, Accuracy: 0.745 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: 0.82971
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.761 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: 0.73006
# [TRAIN] Epoch: 13, Iter: 80, Loss: 0.74741
# [TRAIN] Epoch: 13, Iter: 160, Loss: 0.64545
# [TRAIN] Epoch: 13, Iter: 240, Loss: 0.62853
# [TRAIN] Epoch: 13, Iter: 320, Loss: 0.86129
# == [TRAIN] Epoch: 13, Accuracy: 0.760 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: 0.73139
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.768 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: 0.64947
# [TRAIN] Epoch: 14, Iter: 80, Loss: 0.86969
# [TRAIN] Epoch: 14, Iter: 160, Loss: 0.71831
# [TRAIN] Epoch: 14, Iter: 240, Loss: 0.69904
# [TRAIN] Epoch: 14, Iter: 320, Loss: 0.60841
# == [TRAIN] Epoch: 14, Accuracy: 0.768 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: 0.71037
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.783 ===>
# [TEST] Epoch: 14, Iter: 0, Loss: 0.72985
# === [TEST] Epoch: 14, Iter: 78, Accuracy: 0.701 ===>
# ===== Best validation Accuracy: 0.783 =====>
# Writing training logs to exps/resnet18_1e-05...

# %%
generate_plots(list_of_dirs=['/content/exps/resnet18_0.1','/content/exps/resnet18_0.01','/content/exps/resnet18_0.001','/content/exps/resnet18_0.0001','/content/exps/resnet18_1e-05'],legend_names=lr,save_path='/content/exps/images_resnet')

# %%
# mlpmixer with 15 epochs
conf = {
    "num_classes": 10,
    "img_size": 32,
    "patch_size": 6,
    "embed_dim": 256,
    "num_blocks": 4,
    "drop_rate": 0.0,
    "activation": "gelu"
}
with open("json_object.json", "w") as outfile:    
  json.dump(conf, outfile)


config = Arguments(model='mlpmixer', 
                    model_config='json_object.json', 
                    epochs=15, logdir="exps/mlpmixer_6")
main_entry(config)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model MLPMIXER...
# Loading model config from json_object.json
# ########## MLPMIXER CONFIG ################
# num_classes:	10
# img_size:	32
# patch_size:	6
# embed_dim:	256
# num_blocks:	4
# drop_rate:	0.0
# activation:	gelu
# ############################################
# Initialized MLPMIXER model with 2163566 total parameters, of which 2163566 are learnable.
# ====== Epoch 0 ======>
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.43918
# [TRAIN] Epoch: 0, Iter: 80, Loss: 1.80181
# [TRAIN] Epoch: 0, Iter: 160, Loss: 1.53727
# [TRAIN] Epoch: 0, Iter: 240, Loss: 1.47026
# [TRAIN] Epoch: 0, Iter: 320, Loss: 1.46480
# == [TRAIN] Epoch: 0, Accuracy: 0.400 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: 1.42861
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.516 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: 1.37059
# [TRAIN] Epoch: 1, Iter: 80, Loss: 1.31608
# [TRAIN] Epoch: 1, Iter: 160, Loss: 1.13554
# [TRAIN] Epoch: 1, Iter: 240, Loss: 1.03291
# [TRAIN] Epoch: 1, Iter: 320, Loss: 1.19393
# == [TRAIN] Epoch: 1, Accuracy: 0.554 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: 1.27069
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.546 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: 1.21569
# [TRAIN] Epoch: 2, Iter: 80, Loss: 1.27332
# [TRAIN] Epoch: 2, Iter: 160, Loss: 0.95859
# [TRAIN] Epoch: 2, Iter: 240, Loss: 1.25455
# [TRAIN] Epoch: 2, Iter: 320, Loss: 1.08887
# == [TRAIN] Epoch: 2, Accuracy: 0.613 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: 1.15613
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.653 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: 1.11228
# [TRAIN] Epoch: 3, Iter: 80, Loss: 0.87677
# [TRAIN] Epoch: 3, Iter: 160, Loss: 0.94001
# [TRAIN] Epoch: 3, Iter: 240, Loss: 0.96471
# [TRAIN] Epoch: 3, Iter: 320, Loss: 0.85643
# == [TRAIN] Epoch: 3, Accuracy: 0.647 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: 1.00558
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.673 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: 0.78923
# [TRAIN] Epoch: 4, Iter: 80, Loss: 0.86243
# [TRAIN] Epoch: 4, Iter: 160, Loss: 0.78952
# [TRAIN] Epoch: 4, Iter: 240, Loss: 0.97021
# [TRAIN] Epoch: 4, Iter: 320, Loss: 0.97737
# == [TRAIN] Epoch: 4, Accuracy: 0.675 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: 1.00010
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.684 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: 0.90145
# [TRAIN] Epoch: 5, Iter: 80, Loss: 0.84552
# [TRAIN] Epoch: 5, Iter: 160, Loss: 1.00435
# [TRAIN] Epoch: 5, Iter: 240, Loss: 0.83263
# [TRAIN] Epoch: 5, Iter: 320, Loss: 0.73709
# == [TRAIN] Epoch: 5, Accuracy: 0.697 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: 0.90995
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.714 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: 0.78030
# [TRAIN] Epoch: 6, Iter: 80, Loss: 0.90250
# [TRAIN] Epoch: 6, Iter: 160, Loss: 0.94108
# [TRAIN] Epoch: 6, Iter: 240, Loss: 0.72904
# [TRAIN] Epoch: 6, Iter: 320, Loss: 0.89312
# == [TRAIN] Epoch: 6, Accuracy: 0.716 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: 0.93065
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.728 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: 0.59726
# [TRAIN] Epoch: 7, Iter: 80, Loss: 0.80239
# [TRAIN] Epoch: 7, Iter: 160, Loss: 0.78404
# [TRAIN] Epoch: 7, Iter: 240, Loss: 0.67989
# [TRAIN] Epoch: 7, Iter: 320, Loss: 0.70486
# == [TRAIN] Epoch: 7, Accuracy: 0.737 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: 0.79485
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.753 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: 0.63011
# [TRAIN] Epoch: 8, Iter: 80, Loss: 0.75086
# [TRAIN] Epoch: 8, Iter: 160, Loss: 0.75317
# [TRAIN] Epoch: 8, Iter: 240, Loss: 0.66887
# [TRAIN] Epoch: 8, Iter: 320, Loss: 0.84163
# == [TRAIN] Epoch: 8, Accuracy: 0.751 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: 0.66892
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.792 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: 0.50312
# [TRAIN] Epoch: 9, Iter: 80, Loss: 0.55462
# [TRAIN] Epoch: 9, Iter: 160, Loss: 0.59470
# [TRAIN] Epoch: 9, Iter: 240, Loss: 0.62574
# [TRAIN] Epoch: 9, Iter: 320, Loss: 0.58913
# == [TRAIN] Epoch: 9, Accuracy: 0.765 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: 0.68012
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.792 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: 0.62657
# [TRAIN] Epoch: 10, Iter: 80, Loss: 0.57528
# [TRAIN] Epoch: 10, Iter: 160, Loss: 0.53237
# [TRAIN] Epoch: 10, Iter: 240, Loss: 0.46067
# [TRAIN] Epoch: 10, Iter: 320, Loss: 0.64521
# == [TRAIN] Epoch: 10, Accuracy: 0.780 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: 0.62768
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.800 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: 0.62322
# [TRAIN] Epoch: 11, Iter: 80, Loss: 0.61604
# [TRAIN] Epoch: 11, Iter: 160, Loss: 0.48888
# [TRAIN] Epoch: 11, Iter: 240, Loss: 0.60981
# [TRAIN] Epoch: 11, Iter: 320, Loss: 0.52480
# == [TRAIN] Epoch: 11, Accuracy: 0.797 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: 0.53595
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.823 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: 0.54198
# [TRAIN] Epoch: 12, Iter: 80, Loss: 0.45324
# [TRAIN] Epoch: 12, Iter: 160, Loss: 0.54276
# [TRAIN] Epoch: 12, Iter: 240, Loss: 0.54784
# [TRAIN] Epoch: 12, Iter: 320, Loss: 0.56646
# == [TRAIN] Epoch: 12, Accuracy: 0.807 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: 0.45339
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.841 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: 0.45116
# [TRAIN] Epoch: 13, Iter: 80, Loss: 0.53435
# [TRAIN] Epoch: 13, Iter: 160, Loss: 0.36765
# [TRAIN] Epoch: 13, Iter: 240, Loss: 0.61080
# [TRAIN] Epoch: 13, Iter: 320, Loss: 0.59100
# == [TRAIN] Epoch: 13, Accuracy: 0.819 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: 0.57661
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.825 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: 0.50042
# [TRAIN] Epoch: 14, Iter: 80, Loss: 0.51004
# [TRAIN] Epoch: 14, Iter: 160, Loss: 0.36223
# [TRAIN] Epoch: 14, Iter: 240, Loss: 0.70733
# [TRAIN] Epoch: 14, Iter: 320, Loss: 0.39117
# == [TRAIN] Epoch: 14, Accuracy: 0.834 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: 0.51309
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.854 ===>
# [TEST] Epoch: 14, Iter: 0, Loss: 0.59380
# === [TEST] Epoch: 14, Iter: 78, Accuracy: 0.750 ===>
# ===== Best validation Accuracy: 0.854 =====>
# Writing training logs to exps/mlpmixer_6...

# %%
generate_plots(list_of_dirs=['/content/exps/mlpmixer_4','/content/exps/mlpmixer_6','/content/exps/mlpmixer_8','/content/exps/mlpmixer_16'],legend_names=[4,6,8,16],save_path='/content/exps/images_mlpmixer')

# %%
# MLP with 15 epochs
# optimizer: str = 'adamw'  # [sgd, momentum, adam, adamw]
# epochs: int = 15
# lr: float = 1e-3
# momentum: float = 0.9
# weight_decay: float = 5e-4
conf={
    "num_classes": 10,
    "img_size": 32,
    "patch_size": 4,
    "embed_dim": 256,
    "num_blocks": 4,
    "drop_rate": 0.0,
    "activation": "relu"
}
with open("json_object.json", "w") as outfile:
    json.dump(conf, outfile)
epochs=[30]
# lr = [0.001,0.0001]
# weight_decay = [0.0005]
# optimizer = ['adamw','adam']
hyperparam=[]
val_acc=[]
train_acc=[]
# for s in optimizer:
#   for i in epochs :
#     for j in lr:
#         for l in weight_decay:
#           config = Arguments(model='mlpmixer', model_config='json_object.json', optimizer=s,epochs=i,lr=j,momentum=0.90,weight_decay=l,logdir="/content/exps")
#           k,y=main_entry(config)
#           val_acc.append(k)
#           train_acc.append(y)
#           hyperparam.append([s,i,j,0.90,l])
#           print([s,i,j,0.90,l])
for i in epochs:
          config = Arguments(model='mlpmixer', model_config='json_object.json',lr=0.0001, epochs=i,logdir="/content/exps")
          k,y=main_entry(config)
          val_acc.append(k)
          train_acc.append(y)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Build model MLPMIXER...
# Loading model config from json_object.json
# ########## MLPMIXER CONFIG ################
# num_classes:	10
# img_size:	32
# patch_size:	4
# embed_dim:	256
# num_blocks:	4
# drop_rate:	0.0
# activation:	relu
# ############################################
# Initialized MLPMIXER model with 2188298 total parameters, of which 2188298 are learnable.
# ====== Epoch 0 ======>
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [TRAIN] Epoch: 0, Iter: 0, Loss: 2.34969
# [TRAIN] Epoch: 0, Iter: 80, Loss: 1.94380
# [TRAIN] Epoch: 0, Iter: 160, Loss: 1.81976
# [TRAIN] Epoch: 0, Iter: 240, Loss: 1.63598
# [TRAIN] Epoch: 0, Iter: 320, Loss: 1.61261
# == [TRAIN] Epoch: 0, Accuracy: 0.347 ==>
# [VAL] Epoch: 0, Iter: 0, Loss: 1.72843
# === [VAL] Epoch: 0, Iter: 39, Accuracy: 0.441 ===>
# ====== Epoch 1 ======>
# [TRAIN] Epoch: 1, Iter: 0, Loss: 1.52465
# [TRAIN] Epoch: 1, Iter: 80, Loss: 1.46130
# [TRAIN] Epoch: 1, Iter: 160, Loss: 1.48844
# [TRAIN] Epoch: 1, Iter: 240, Loss: 1.47060
# [TRAIN] Epoch: 1, Iter: 320, Loss: 1.38951
# == [TRAIN] Epoch: 1, Accuracy: 0.477 ==>
# [VAL] Epoch: 1, Iter: 0, Loss: 1.46568
# === [VAL] Epoch: 1, Iter: 39, Accuracy: 0.516 ===>
# ====== Epoch 2 ======>
# [TRAIN] Epoch: 2, Iter: 0, Loss: 1.54982
# [TRAIN] Epoch: 2, Iter: 80, Loss: 1.45803
# [TRAIN] Epoch: 2, Iter: 160, Loss: 1.22245
# [TRAIN] Epoch: 2, Iter: 240, Loss: 1.33768
# [TRAIN] Epoch: 2, Iter: 320, Loss: 1.41137
# == [TRAIN] Epoch: 2, Accuracy: 0.523 ==>
# [VAL] Epoch: 2, Iter: 0, Loss: 1.42729
# === [VAL] Epoch: 2, Iter: 39, Accuracy: 0.521 ===>
# ====== Epoch 3 ======>
# [TRAIN] Epoch: 3, Iter: 0, Loss: 1.49776
# [TRAIN] Epoch: 3, Iter: 80, Loss: 1.32315
# [TRAIN] Epoch: 3, Iter: 160, Loss: 1.32273
# [TRAIN] Epoch: 3, Iter: 240, Loss: 1.03113
# [TRAIN] Epoch: 3, Iter: 320, Loss: 1.32553
# == [TRAIN] Epoch: 3, Accuracy: 0.556 ==>
# [VAL] Epoch: 3, Iter: 0, Loss: 1.32592
# === [VAL] Epoch: 3, Iter: 39, Accuracy: 0.567 ===>
# ====== Epoch 4 ======>
# [TRAIN] Epoch: 4, Iter: 0, Loss: 1.15594
# [TRAIN] Epoch: 4, Iter: 80, Loss: 1.15709
# [TRAIN] Epoch: 4, Iter: 160, Loss: 1.04958
# [TRAIN] Epoch: 4, Iter: 240, Loss: 1.15674
# [TRAIN] Epoch: 4, Iter: 320, Loss: 1.18831
# == [TRAIN] Epoch: 4, Accuracy: 0.577 ==>
# [VAL] Epoch: 4, Iter: 0, Loss: 1.35367
# === [VAL] Epoch: 4, Iter: 39, Accuracy: 0.572 ===>
# ====== Epoch 5 ======>
# [TRAIN] Epoch: 5, Iter: 0, Loss: 1.31276
# [TRAIN] Epoch: 5, Iter: 80, Loss: 1.27503
# [TRAIN] Epoch: 5, Iter: 160, Loss: 1.23907
# [TRAIN] Epoch: 5, Iter: 240, Loss: 1.14844
# [TRAIN] Epoch: 5, Iter: 320, Loss: 1.06439
# == [TRAIN] Epoch: 5, Accuracy: 0.594 ==>
# [VAL] Epoch: 5, Iter: 0, Loss: 1.20878
# === [VAL] Epoch: 5, Iter: 39, Accuracy: 0.605 ===>
# ====== Epoch 6 ======>
# [TRAIN] Epoch: 6, Iter: 0, Loss: 1.12457
# [TRAIN] Epoch: 6, Iter: 80, Loss: 0.96991
# [TRAIN] Epoch: 6, Iter: 160, Loss: 1.02475
# [TRAIN] Epoch: 6, Iter: 240, Loss: 1.04350
# [TRAIN] Epoch: 6, Iter: 320, Loss: 1.29321
# == [TRAIN] Epoch: 6, Accuracy: 0.616 ==>
# [VAL] Epoch: 6, Iter: 0, Loss: 1.16572
# === [VAL] Epoch: 6, Iter: 39, Accuracy: 0.625 ===>
# ====== Epoch 7 ======>
# [TRAIN] Epoch: 7, Iter: 0, Loss: 1.09531
# [TRAIN] Epoch: 7, Iter: 80, Loss: 0.97486
# [TRAIN] Epoch: 7, Iter: 160, Loss: 1.17286
# [TRAIN] Epoch: 7, Iter: 240, Loss: 0.98134
# [TRAIN] Epoch: 7, Iter: 320, Loss: 1.08929
# == [TRAIN] Epoch: 7, Accuracy: 0.626 ==>
# [VAL] Epoch: 7, Iter: 0, Loss: 1.13017
# === [VAL] Epoch: 7, Iter: 39, Accuracy: 0.629 ===>
# ====== Epoch 8 ======>
# [TRAIN] Epoch: 8, Iter: 0, Loss: 1.02879
# [TRAIN] Epoch: 8, Iter: 80, Loss: 1.10241
# [TRAIN] Epoch: 8, Iter: 160, Loss: 1.18204
# [TRAIN] Epoch: 8, Iter: 240, Loss: 1.02275
# [TRAIN] Epoch: 8, Iter: 320, Loss: 0.98915
# == [TRAIN] Epoch: 8, Accuracy: 0.637 ==>
# [VAL] Epoch: 8, Iter: 0, Loss: 1.02408
# === [VAL] Epoch: 8, Iter: 39, Accuracy: 0.648 ===>
# ====== Epoch 9 ======>
# [TRAIN] Epoch: 9, Iter: 0, Loss: 0.95610
# [TRAIN] Epoch: 9, Iter: 80, Loss: 1.04621
# [TRAIN] Epoch: 9, Iter: 160, Loss: 1.04898
# [TRAIN] Epoch: 9, Iter: 240, Loss: 1.06750
# [TRAIN] Epoch: 9, Iter: 320, Loss: 1.04270
# == [TRAIN] Epoch: 9, Accuracy: 0.649 ==>
# [VAL] Epoch: 9, Iter: 0, Loss: 0.97927
# === [VAL] Epoch: 9, Iter: 39, Accuracy: 0.654 ===>
# ====== Epoch 10 ======>
# [TRAIN] Epoch: 10, Iter: 0, Loss: 0.97547
# [TRAIN] Epoch: 10, Iter: 80, Loss: 0.97661
# [TRAIN] Epoch: 10, Iter: 160, Loss: 1.06533
# [TRAIN] Epoch: 10, Iter: 240, Loss: 0.88885
# [TRAIN] Epoch: 10, Iter: 320, Loss: 0.84083
# == [TRAIN] Epoch: 10, Accuracy: 0.661 ==>
# [VAL] Epoch: 10, Iter: 0, Loss: 0.97762
# === [VAL] Epoch: 10, Iter: 39, Accuracy: 0.682 ===>
# ====== Epoch 11 ======>
# [TRAIN] Epoch: 11, Iter: 0, Loss: 0.96991
# [TRAIN] Epoch: 11, Iter: 80, Loss: 0.95966
# [TRAIN] Epoch: 11, Iter: 160, Loss: 0.91794
# [TRAIN] Epoch: 11, Iter: 240, Loss: 0.93849
# [TRAIN] Epoch: 11, Iter: 320, Loss: 0.88847
# == [TRAIN] Epoch: 11, Accuracy: 0.670 ==>
# [VAL] Epoch: 11, Iter: 0, Loss: 0.98445
# === [VAL] Epoch: 11, Iter: 39, Accuracy: 0.683 ===>
# ====== Epoch 12 ======>
# [TRAIN] Epoch: 12, Iter: 0, Loss: 1.02756
# [TRAIN] Epoch: 12, Iter: 80, Loss: 0.85002
# [TRAIN] Epoch: 12, Iter: 160, Loss: 1.01643
# [TRAIN] Epoch: 12, Iter: 240, Loss: 0.82461
# [TRAIN] Epoch: 12, Iter: 320, Loss: 1.09269
# == [TRAIN] Epoch: 12, Accuracy: 0.678 ==>
# [VAL] Epoch: 12, Iter: 0, Loss: 1.01192
# === [VAL] Epoch: 12, Iter: 39, Accuracy: 0.686 ===>
# ====== Epoch 13 ======>
# [TRAIN] Epoch: 13, Iter: 0, Loss: 0.96254
# [TRAIN] Epoch: 13, Iter: 80, Loss: 0.89203
# [TRAIN] Epoch: 13, Iter: 160, Loss: 1.12733
# [TRAIN] Epoch: 13, Iter: 240, Loss: 0.80022
# [TRAIN] Epoch: 13, Iter: 320, Loss: 0.88697
# == [TRAIN] Epoch: 13, Accuracy: 0.683 ==>
# [VAL] Epoch: 13, Iter: 0, Loss: 0.95071
# === [VAL] Epoch: 13, Iter: 39, Accuracy: 0.691 ===>
# ====== Epoch 14 ======>
# [TRAIN] Epoch: 14, Iter: 0, Loss: 0.82447
# [TRAIN] Epoch: 14, Iter: 80, Loss: 0.80331
# [TRAIN] Epoch: 14, Iter: 160, Loss: 0.87300
# [TRAIN] Epoch: 14, Iter: 240, Loss: 0.90082
# [TRAIN] Epoch: 14, Iter: 320, Loss: 0.82804
# == [TRAIN] Epoch: 14, Accuracy: 0.694 ==>
# [VAL] Epoch: 14, Iter: 0, Loss: 0.90585
# === [VAL] Epoch: 14, Iter: 39, Accuracy: 0.713 ===>
# ====== Epoch 15 ======>
# [TRAIN] Epoch: 15, Iter: 0, Loss: 0.94763
# [TRAIN] Epoch: 15, Iter: 80, Loss: 0.79923
# [TRAIN] Epoch: 15, Iter: 160, Loss: 0.87282
# [TRAIN] Epoch: 15, Iter: 240, Loss: 0.74142
# [TRAIN] Epoch: 15, Iter: 320, Loss: 0.72249
# == [TRAIN] Epoch: 15, Accuracy: 0.701 ==>
# [VAL] Epoch: 15, Iter: 0, Loss: 0.95441
# === [VAL] Epoch: 15, Iter: 39, Accuracy: 0.713 ===>
# ====== Epoch 16 ======>
# [TRAIN] Epoch: 16, Iter: 0, Loss: 0.98186
# [TRAIN] Epoch: 16, Iter: 80, Loss: 0.87838
# [TRAIN] Epoch: 16, Iter: 160, Loss: 0.68700
# [TRAIN] Epoch: 16, Iter: 240, Loss: 0.82411
# [TRAIN] Epoch: 16, Iter: 320, Loss: 0.95342
# == [TRAIN] Epoch: 16, Accuracy: 0.705 ==>
# [VAL] Epoch: 16, Iter: 0, Loss: 0.87420
# === [VAL] Epoch: 16, Iter: 39, Accuracy: 0.734 ===>
# ====== Epoch 17 ======>
# [TRAIN] Epoch: 17, Iter: 0, Loss: 0.81354
# [TRAIN] Epoch: 17, Iter: 80, Loss: 1.06996
# [TRAIN] Epoch: 17, Iter: 160, Loss: 0.80005
# [TRAIN] Epoch: 17, Iter: 240, Loss: 0.78275
# [TRAIN] Epoch: 17, Iter: 320, Loss: 0.86809
# == [TRAIN] Epoch: 17, Accuracy: 0.712 ==>
# [VAL] Epoch: 17, Iter: 0, Loss: 0.86999
# === [VAL] Epoch: 17, Iter: 39, Accuracy: 0.729 ===>
# ====== Epoch 18 ======>
# [TRAIN] Epoch: 18, Iter: 0, Loss: 0.84008
# [TRAIN] Epoch: 18, Iter: 80, Loss: 0.72779
# [TRAIN] Epoch: 18, Iter: 160, Loss: 0.78561
# [TRAIN] Epoch: 18, Iter: 240, Loss: 0.85254
# [TRAIN] Epoch: 18, Iter: 320, Loss: 0.77658
# == [TRAIN] Epoch: 18, Accuracy: 0.720 ==>
# [VAL] Epoch: 18, Iter: 0, Loss: 0.87473
# === [VAL] Epoch: 18, Iter: 39, Accuracy: 0.720 ===>
# ====== Epoch 19 ======>
# [TRAIN] Epoch: 19, Iter: 0, Loss: 0.65143
# [TRAIN] Epoch: 19, Iter: 80, Loss: 0.92164
# [TRAIN] Epoch: 19, Iter: 160, Loss: 0.77263
# [TRAIN] Epoch: 19, Iter: 240, Loss: 0.70740
# [TRAIN] Epoch: 19, Iter: 320, Loss: 0.82660
# == [TRAIN] Epoch: 19, Accuracy: 0.728 ==>
# [VAL] Epoch: 19, Iter: 0, Loss: 0.83455
# === [VAL] Epoch: 19, Iter: 39, Accuracy: 0.724 ===>
# ====== Epoch 20 ======>
# [TRAIN] Epoch: 20, Iter: 0, Loss: 0.69006
# [TRAIN] Epoch: 20, Iter: 80, Loss: 0.58037
# [TRAIN] Epoch: 20, Iter: 160, Loss: 0.85713
# [TRAIN] Epoch: 20, Iter: 240, Loss: 1.05227
# [TRAIN] Epoch: 20, Iter: 320, Loss: 0.57901
# == [TRAIN] Epoch: 20, Accuracy: 0.733 ==>
# [VAL] Epoch: 20, Iter: 0, Loss: 0.83079
# === [VAL] Epoch: 20, Iter: 39, Accuracy: 0.745 ===>
# ====== Epoch 21 ======>
# [TRAIN] Epoch: 21, Iter: 0, Loss: 0.82450
# [TRAIN] Epoch: 21, Iter: 80, Loss: 0.77266
# [TRAIN] Epoch: 21, Iter: 160, Loss: 0.68778
# [TRAIN] Epoch: 21, Iter: 240, Loss: 0.83780
# [TRAIN] Epoch: 21, Iter: 320, Loss: 0.78297
# == [TRAIN] Epoch: 21, Accuracy: 0.743 ==>
# [VAL] Epoch: 21, Iter: 0, Loss: 0.91374
# === [VAL] Epoch: 21, Iter: 39, Accuracy: 0.743 ===>
# ====== Epoch 22 ======>
# [TRAIN] Epoch: 22, Iter: 0, Loss: 0.58312
# [TRAIN] Epoch: 22, Iter: 80, Loss: 0.54156
# [TRAIN] Epoch: 22, Iter: 160, Loss: 0.90810
# [TRAIN] Epoch: 22, Iter: 240, Loss: 0.68358
# [TRAIN] Epoch: 22, Iter: 320, Loss: 0.62550
# == [TRAIN] Epoch: 22, Accuracy: 0.748 ==>
# [VAL] Epoch: 22, Iter: 0, Loss: 0.79633
# === [VAL] Epoch: 22, Iter: 39, Accuracy: 0.764 ===>
# ====== Epoch 23 ======>
# [TRAIN] Epoch: 23, Iter: 0, Loss: 0.64450
# [TRAIN] Epoch: 23, Iter: 80, Loss: 0.70123
# [TRAIN] Epoch: 23, Iter: 160, Loss: 0.64261
# [TRAIN] Epoch: 23, Iter: 240, Loss: 0.50193
# [TRAIN] Epoch: 23, Iter: 320, Loss: 0.87562
# == [TRAIN] Epoch: 23, Accuracy: 0.754 ==>
# [VAL] Epoch: 23, Iter: 0, Loss: 0.83610
# === [VAL] Epoch: 23, Iter: 39, Accuracy: 0.767 ===>
# ====== Epoch 24 ======>
# [TRAIN] Epoch: 24, Iter: 0, Loss: 0.63544
# [TRAIN] Epoch: 24, Iter: 80, Loss: 0.85878
# [TRAIN] Epoch: 24, Iter: 160, Loss: 0.61938
# [TRAIN] Epoch: 24, Iter: 240, Loss: 0.58848
# [TRAIN] Epoch: 24, Iter: 320, Loss: 0.68389
# == [TRAIN] Epoch: 24, Accuracy: 0.761 ==>
# [VAL] Epoch: 24, Iter: 0, Loss: 0.76846
# === [VAL] Epoch: 24, Iter: 39, Accuracy: 0.770 ===>
# ====== Epoch 25 ======>
# [TRAIN] Epoch: 25, Iter: 0, Loss: 0.73083
# [TRAIN] Epoch: 25, Iter: 80, Loss: 0.58193
# [TRAIN] Epoch: 25, Iter: 160, Loss: 0.70967
# [TRAIN] Epoch: 25, Iter: 240, Loss: 0.82087
# [TRAIN] Epoch: 25, Iter: 320, Loss: 0.59138
# == [TRAIN] Epoch: 25, Accuracy: 0.766 ==>
# [VAL] Epoch: 25, Iter: 0, Loss: 0.72936
# === [VAL] Epoch: 25, Iter: 39, Accuracy: 0.782 ===>
# ====== Epoch 26 ======>
# [TRAIN] Epoch: 26, Iter: 0, Loss: 0.62766
# [TRAIN] Epoch: 26, Iter: 80, Loss: 0.61586
# [TRAIN] Epoch: 26, Iter: 160, Loss: 0.58215
# [TRAIN] Epoch: 26, Iter: 240, Loss: 0.50017
# [TRAIN] Epoch: 26, Iter: 320, Loss: 0.46968
# == [TRAIN] Epoch: 26, Accuracy: 0.774 ==>
# [VAL] Epoch: 26, Iter: 0, Loss: 0.76997
# === [VAL] Epoch: 26, Iter: 39, Accuracy: 0.777 ===>
# ====== Epoch 27 ======>
# [TRAIN] Epoch: 27, Iter: 0, Loss: 0.65044
# [TRAIN] Epoch: 27, Iter: 80, Loss: 0.56345
# [TRAIN] Epoch: 27, Iter: 160, Loss: 0.54821
# [TRAIN] Epoch: 27, Iter: 240, Loss: 0.55901
# [TRAIN] Epoch: 27, Iter: 320, Loss: 0.78402
# == [TRAIN] Epoch: 27, Accuracy: 0.778 ==>
# [VAL] Epoch: 27, Iter: 0, Loss: 0.74196
# === [VAL] Epoch: 27, Iter: 39, Accuracy: 0.803 ===>
# ====== Epoch 28 ======>
# [TRAIN] Epoch: 28, Iter: 0, Loss: 0.73798
# [TRAIN] Epoch: 28, Iter: 80, Loss: 0.57274
# [TRAIN] Epoch: 28, Iter: 160, Loss: 0.66156
# [TRAIN] Epoch: 28, Iter: 240, Loss: 0.59548
# [TRAIN] Epoch: 28, Iter: 320, Loss: 0.83205
# == [TRAIN] Epoch: 28, Accuracy: 0.783 ==>
# [VAL] Epoch: 28, Iter: 0, Loss: 0.70611
# === [VAL] Epoch: 28, Iter: 39, Accuracy: 0.808 ===>
# ====== Epoch 29 ======>
# [TRAIN] Epoch: 29, Iter: 0, Loss: 0.54680
# [TRAIN] Epoch: 29, Iter: 80, Loss: 0.59942
# [TRAIN] Epoch: 29, Iter: 160, Loss: 0.69915
# [TRAIN] Epoch: 29, Iter: 240, Loss: 0.58609
# [TRAIN] Epoch: 29, Iter: 320, Loss: 0.63929
# == [TRAIN] Epoch: 29, Accuracy: 0.788 ==>
# [VAL] Epoch: 29, Iter: 0, Loss: 0.73103
# === [VAL] Epoch: 29, Iter: 39, Accuracy: 0.773 ===>
# [TEST] Epoch: 29, Iter: 0, Loss: 0.76804
# === [TEST] Epoch: 29, Iter: 78, Accuracy: 0.696 ===>
# ===== Best validation Accuracy: 0.808 =====>
# Writing training logs to /content/exps...

# %%
train_acc
# Out:
# [0.901264245014245, 0.9353855056980042]

# %%
from mlpmixer import MLPMixer
model=MLPMixer(num_classes= 10,
    img_size= 32,
   patch_size= 4,
    embed_dim= 256,
    num_blocks= 4,
    drop_rate= 0.0,
    activation= "gelu")
model.visualize('/content/sample_data')

# %%
import pandas as pd
df=pd.DataFrame(k,columns=[['Optimizer','Epochs','Learning Rate','Momentum','weight_decay','Train Accuracy','Validation Accuracy']])
df
# Out:
#    Optimizer Epochs Learning Rate Momentum weight_decay Train Accuracy  \
# 0      adamw     25        0.0010     0.96       0.0006       0.963364
# 1      adamw     25        0.0010     0.96       0.0007       0.963631
# 2      adamw     20        0.0001     0.95       0.0005       0.951589
# 3      adamw     20        0.0001     0.95       0.0006       0.950788
# 4       adam     15        0.0010     0.99       0.0005       0.927417
# 5       adam     15        0.0010     0.99       0.0006       0.923811
# 6       adam     15        0.0001     0.99       0.0005       0.925258
# 7       adam     15        0.0001     0.99       0.0006       0.924368
# 8        sgd     20        0.0010     0.90       0.0004       0.700298
# 9        sgd     20        0.0010     0.90       0.0003       0.699007
# 10  momentum     20        0.0010     0.90       0.0004       0.926215
# 11  momentum     20        0.0010     0.90       0.0003       0.924524
#
#    Validation Accuracy
# 0             0.976367
# 1             0.972852
# 2             0.954102
# 3             0.956641
# 4             0.941016
# 5             0.944531
# 6             0.928711
# 7             0.928711
# 8             0.707813
# 9             0.719141
# 10            0.923828
# 11            0.928516
